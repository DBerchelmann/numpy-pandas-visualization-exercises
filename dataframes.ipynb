# %%
import pandas as pd

# %%
import numpy as np

# %%
from pydataset import data

# %%
mpg = data('mpg')

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df)
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   math     12 non-null     int64
#  2   english  12 non-null     int64
#  3   reading  12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %%
df.describe()
# Out:
#             math    english    reading
# count  12.000000  12.000000  12.000000
# mean   84.833333  77.666667  86.500000
# std    11.134168  13.371158   9.643651
# min    62.000000  62.000000  67.000000
# 25%    78.500000  63.750000  80.750000
# 50%    90.000000  77.500000  89.000000
# 75%    92.250000  86.750000  93.250000
# max    98.000000  99.000000  98.000000

# %%
df.dtypes
# Out:
# name       object
# math        int64
# english     int64
# reading     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['name', 'math', 'english', 'reading'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
# 1 Copy the code from the lesson to create a dataframe full of student grades.

# %%
# Create a column named passing_english that indicates whether each student has a passing grade in english.

df['passing_english'] = df.english > 70

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
# Sort the english grades by the passing_english column. How are duplicates handled?

df.sort_values(by='passing_english')

# duplicate false values are ordered by index in ASC order
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
# Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically.
# The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)



df.sort_values(['passing_english', 'name'], ascending=[True, True])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

df.sort_values(['passing_english', 'english'], ascending=[False, False])
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 10    Isaac    92       99       93             True           95.0
# 3     Billy    98       96       88             True           94.0
# 4       Ada    77       92       98             True           89.0
# 0     Sally    62       85       80             True           76.0
# 9   Richard    69       80       94             True           81.0
# 1      Jane    88       79       67             True           78.0
# 5      John    79       76       93             True           83.0
# 2     Suzie    94       74       95             True           88.0
# 6    Thomas    82       64       81            False           76.0
# 7     Marie    93       63       90            False           82.0
# 8    Albert    92       62       87            False           80.0
# 11     Alan    92       62       72            False           75.0

# %%
# Calculate each students overall grade and add it as a column on the dataframe. 
# The overall grade is the average of the math, english, and reading grades.

#df['overall_average'] = df.sum(axis=1)

df['overall_average'] = df[['math', 'english', 'reading']].mean(numeric_only = True, axis=1).round()

df

# could also use the .loc attribute df.loc[:, 'math': 'reading'] labels are not exclusive, includes reading

# df.iloc[:, 1:4]   :, (means all rows selected)
# Out:
#        name  math  english  reading  passing_english  overall_grade  \
# 0     Sally    62       85       80             True           76.0
# 1      Jane    88       79       67             True           78.0
# 2     Suzie    94       74       95             True           88.0
# 3     Billy    98       96       88             True           94.0
# 4       Ada    77       92       98             True           89.0
# 5      John    79       76       93             True           83.0
# 6    Thomas    82       64       81            False           76.0
# 7     Marie    93       63       90            False           82.0
# 8    Albert    92       62       87            False           80.0
# 9   Richard    69       80       94             True           81.0
# 10    Isaac    92       99       93             True           95.0
# 11     Alan    92       62       72            False           75.0
#
#     overall_average
# 0              76.0
# 1              78.0
# ...

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg.shape
# Out:
# (234, 14)

# %%
# 2 How many rows and columns are there? There are 234 rows and 11 columns

# %%
# What are the data types of each column?

mpg.info()

mpg.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   manufacturer        234 non-null    object
#  1   model               234 non-null    object
#  2   displ               234 non-null    float64
#  3   year                234 non-null    int64
#  4   cyl                 234 non-null    int64
#  5   trans               234 non-null    object
#  6   drv                 234 non-null    object
#  7   city                234 non-null    int64
#  8   highway             234 non-null    int64
#  9   fl                  234 non-null    object
#  10  class               234 non-null    object
#  11  better_citymileage  234 non-null    bool
#  12  mileage_difference  234 non-null    int64
#  13  average_mileage     234 non-null    float64
# dtypes: bool(1), float64(2), int64(5), object(6)
# memory usage: 35.8+ KB
# ...

# %%
# Summarize the dataframe with .info and .describe

mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
# Rename the cty column to city



mpg.rename(columns={'cty': 'city'}, inplace=True)

# %%
mpg.rename(columns={'cty': 'city', 'hwy': 'highway'}, inplace=True)

# %%
mpg.head(1) # check to see column names have been changed
# Out:
#   manufacturer model  displ  year  cyl     trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4  auto(l5)   f    18       29  p
#
#      class  better_citymileage  mileage_difference  average_mileage
# 1  compact               False                  11             23.5

# %%
mpg.columns.tolist() # will list out all column names.
# Out:
# ['manufacturer',
#  'model',
#  'displ',
#  'year',
#  'cyl',
#  'trans',
#  'drv',
#  'city',
#  'highway',
#  'fl',
#  'class',
#  'better_citymileage',
#  'mileage_difference',
#  'average_mileage']

# %%
# Do any cars have better city mileage than highway mileage? # no

mpg['better_citymileage'] = mpg.city > mpg.highway

mpg.sort_values(['better_citymileage'], ascending=[False])
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  city  \
# 1           audi               a4    1.8  1999    4    auto(l5)   f    18
# 161       subaru     forester awd    2.5  1999    4    auto(l4)   4    18
# 149       nissan           maxima    3.0  1999    6  manual(m5)   f    19
# 150       nissan           maxima    3.5  2008    6    auto(av)   f    19
# 151       nissan   pathfinder 4wd    3.3  1999    6    auto(l4)   4    14
# ..           ...              ...    ...   ...  ...         ...  ..   ...
# 83          ford     explorer 4wd    5.0  1999    8    auto(l4)   4    13
# 84          ford  f150 pickup 4wd    4.2  1999    6    auto(l4)   4    14
# 85          ford  f150 pickup 4wd    4.2  1999    6  manual(m5)   4    14
# 86          ford  f150 pickup 4wd    4.6  1999    8  manual(m5)   4    13
# 234   volkswagen           passat    3.6  2008    6    auto(s6)   f    17
#
#      highway fl    class  better_citymileage
# ...

# %%
bool_series = mpg.city>mpg.highway
bool_series.head()
# Out:
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
mpg[bool_series] #shows none
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class, better_citymileage, mileage_difference, average_mileage]
# Index: []

# %%
# Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

mpg['mileage_difference'] = mpg.highway - mpg.city

mpg.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  better_citymileage  mileage_difference  average_mileage
# 1  compact               False                  11             23.5
# 2  compact               False                   8             25.0
# 3  compact               False                  11             25.5
# 4  compact               False                   9             25.5
# 5  compact               False                  10             21.0

# %%
mpg = mpg.drop(columns=['mileage_differnce'])

# %%
# Which car (or cars) has the highest mileage difference?

mpg.loc[mpg.groupby('model')['mileage_difference'].idxmax()].sort_values(['mileage_difference'], ascending=[False]) 
   
    
# could also do...   mpg.nlargest(1, 'mileage_difference', keep='all')
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 107        honda                   civic    1.8  2008    4    auto(l5)   f
# 36     chevrolet                  malibu    3.5  2008    6    auto(l4)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 229   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 112      hyundai                  sonata    2.4  2008    4  manual(m5)   f
# 117      hyundai                 tiburon    2.0  1999    4  manual(m5)   f
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 156      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 189       toyota            camry solara    2.4  2008    4  manual(m5)   f
# ...

# %%
# Which compact class car has the lowest highway mileage? The best?

mpg.loc[mpg.groupby('class')['highway'].idxmin()]
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 25     chevrolet           corvette    5.7  1999    8    auto(l4)   r    15
# 220   volkswagen              jetta    2.8  1999    6    auto(l4)   f    16
# 18          audi         a6 quattro    4.2  2008    8    auto(s6)   4    16
# 44         dodge        caravan 2wd    3.3  2008    6    auto(l4)   f    11
# 55         dodge  dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 99          ford            mustang    5.4  2008    8  manual(m6)   r    14
# 60         dodge        durango 4wd    4.7  2008    8    auto(l5)   4     9
#
#      highway fl       class  better_citymileage  mileage_difference
# 25        23  p     2seater               False                   8
# 220       23  r     compact               False                   7
# 18        23  p     midsize               False                   7
# 44        17  e     minivan               False                   6
# ...

# %%
mpg.loc[mpg.groupby('class')['highway'].idxmax()]
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 24     chevrolet           corvette    5.7  1999    8  manual(m6)   r    16
# 213   volkswagen              jetta    1.9  1999    4  manual(m5)   f    33
# 145       nissan             altima    2.5  2008    4  manual(m6)   f    23
# 38         dodge        caravan 2wd    2.4  1999    4    auto(l3)   f    18
# 203       toyota  toyota tacoma 4wd    2.7  2008    4  manual(m5)   4    17
# 222   volkswagen         new beetle    1.9  1999    4  manual(m5)   f    35
# 162       subaru       forester awd    2.5  2008    4  manual(m5)   4    20
#
#      highway fl       class  better_citymileage  mileage_difference  \
# 24        26  p     2seater               False                  10
# 213       44  d     compact               False                  11
# 145       32  r     midsize               False                   9
# 38        24  r     minivan               False                   6
# ...

# %%
# Create a column named average_mileage that is the mean of the city and highway mileage.

mpg['average_mileage'] = mpg[['city', 'highway']].mean(numeric_only = True, axis=1)

mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
# Which dodge car has the best average mileage? The worst?

type(mpg['manufacturer']) # this shows that this is a pandas series

mpg['manufacturer'].shape
# Out:
# (234,)

# %%
dodge_cars_max = mpg[(mpg['manufacturer'] == 'dodge') & (mpg['average_mileage'] > 18)]

dodge_cars_max
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
# 39        dodge  caravan 2wd    3.0  1999    6  auto(l4)   f    17       24
# 40        dodge  caravan 2wd    3.3  1999    6  auto(l4)   f    16       22
# 41        dodge  caravan 2wd    3.3  1999    6  auto(l4)   f    16       22
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 43        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 45        dodge  caravan 2wd    3.8  1999    6  auto(l4)   f    15       22
# 47        dodge  caravan 2wd    3.8  2008    6  auto(l6)   f    16       23
# 48        dodge  caravan 2wd    4.0  2008    6  auto(l6)   f    16       23
#
#    fl    class  better_citymileage  mileage_difference  average_mileage
# 38  r  minivan               False                   6             21.0
# ...

# %%
dodge_cars_max.max()
# Out:
# manufacturer                dodge
# model                 caravan 2wd
# displ                           4
# year                         2008
# cyl                             6
# trans                    auto(l6)
# drv                             f
# city                           18
# highway                        24
# fl                              r
# class                     minivan
# better_citymileage          False
# mileage_difference              7
# average_mileage                21
# dtype: object

# %%
dodge_cars_min = mpg[(mpg['manufacturer'] == 'dodge') & (mpg['average_mileage'] < 11)]

dodge_cars_min
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  better_citymileage  mileage_difference  \
# 55       12  e  pickup               False                   3
# 60       12  e     suv               False                   3
# 66       12  e  pickup               False                   3
# 70       12  e  pickup               False                   3
#
#     average_mileage
# 55             10.5
# 60             10.5
# 66             10.5
# 70             10.5

# %%
dodge_cars_min.min()
# Out:
# manufacturer                      dodge
# model                 dakota pickup 4wd
# displ                               4.7
# year                               2008
# cyl                                   8
# trans                          auto(l5)
# drv                                   4
# city                                  9
# highway                              12
# fl                                    e
# class                            pickup
# better_citymileage                False
# mileage_difference                    3
# average_mileage                    10.5
# dtype: object

# %%
# Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

mammals = data('Mammals')

# %%
type(mammals)
# Out:
# pandas.core.frame.DataFrame

# %%
mammals.shape
# Out:
# (107, 4)

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
# How many rows and columns are there?

# 107 rows and 4 columns

# %%
# What are the data types?

mammals.info()  # 2 columns are integers and 2 columns are bools (true/false)

mammals.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
#Summarize the dataframe with .info and .describe

mammals.info() # shows the data-types of the columns

mammals.describe() # shows the count, mean, min, std, max
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
# What is the the weight of the fastest animal?

fastest_animal = mammals[mammals['speed'] == mammals['speed'].max()]

# %%
fastest_animal
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
mammals.nlargest(1, 'speed', keep='all')
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
mammals.specials.sum() # shows total number of specials
# Out:
# 10

# %%
# What is the overal percentage of specials?

entries_overall = 107

total_true_specials = len(mammals[mammals['specials'] == True]) # took total number of entries where special == True


overall_percentage = ((total_true_specials / entries_overall) * 100) #took number of True and divded by total entries overall

print(f'{round(overall_percentage, 2)}% of mammals are specials.')
# Out:
# 9.35% of mammals are specials.

# %%
# How many animals are hoppers that are above the median speed? What percentage is this?

mammals.median() # median speed is 48
# Out:
# weight      34.0
# speed       48.0
# hoppers      0.0
# specials     0.0
# dtype: float64

# %%
median_hoppers = mammals[(mammals['speed'] >= 48.0) & (mammals['hoppers'] == True)] # this shows us all the hoppers with a speed equal to or great than 48

# There are 7 hoppers that are faster than the median speed of 48.0

percentage_of_median_hoppers = (len(median_hoppers)/107) * 100 

percentage_of_median_hoppers

# The percentage of animals that are hoppers and greater than the median speed is 6.5%
# Out:
# 6.5420560747663545
